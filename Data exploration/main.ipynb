# %% [markdown]
# <h1>Exploratory data Analysis with pandas</h1>
# <h3>Start by installing necessary libraries ie pandas and numpy</h3>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# reading the csv files for data

# %%
url = "https://raw.githubusercontent.com/Yorko/mlcourse.ai/main/data/telecom_churn.csv"
df = pd.read_csv(url)
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.shape
# Out:
# (3333, 20)

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# Converting types

# %%
df["Churn"] = df["Churn"].astype("int64")

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                       int64
# dtype: object

# %% [markdown]
# Normalize in value counts outputs the values as a fraction of the total value

# %%
df.Churn.value_counts(normalize=True)
# Out:
# Churn
# 0    0.855086
# 1    0.144914
# Name: proportion, dtype: float64

# %% [markdown]
# To obtain the statistical values of given columns we use .describe() method adding non-numerical features use include

# %%
describe_all = df.describe(include=['object', 'bool', 'int64', 'float64'])
numeric_description = df.describe()
numeric_description
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# <h1>sorting</h1>
# We can sort by specific columns or multiple columns and also by index

# %%
# sorting by a specific columns
df.sort_values(by= "Total day charge", ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 365                       0              350.8               75
# 985                       0              346.8               55
# 2594                      0              345.3               81
# 156                       0              337.4              120
# 605                       0              335.5               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
# sorting by multiple columns
df.sort_values(by=["Churn", "Total day charge"], ascending=[True, False] ).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 688     MN              13        510                 No             Yes
# 2259    NC             210        415                 No             Yes
# 534     LA              67        510                 No              No
# 575     SD             114        415                 No             Yes
# 2858    AL             141        510                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 688                      21              315.6              105
# 2259                     31              313.8               87
# 534                       0              310.4               97
# 575                      36              309.9               90
# 2858                     28              308.0              123
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
# by index
df.sort_index(axis=0, ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3332    TN              74        415                 No             Yes
# 3331    CT             184        510                Yes              No
# 3330    RI              28        510                 No              No
# 3329    WV              68        415                 No              No
# 3328    AZ             192        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3332                     25              234.4              113
# 3331                      0              213.8              105
# 3330                      0              180.8              109
# 3329                      0              231.1               57
# 3328                     36              156.2               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %% [markdown]
# <h1>Indexing and Data Retrieval</h1>

# %%
# fetching a column
#can be done in two ways
# way one 
df["Churn"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: Churn, Length: 3333, dtype: int64

# %%
# second way
df.Churn
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: Churn, Length: 3333, dtype: int64

# %%
# The average values  of numeric features for churned users
df.select_dtypes(include=np.number)[df['Churn'] == 1].mean()
# Out:
# Account length            102.664596
# Area code                 437.817805
# Number vmail messages       5.115942
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %%
# the average time spent by churned users per day
df[df["Churn"] == 1]["Total day minutes"].mean()
# Out:
# np.float64(206.91407867494823)

# %%
# Maximum length of international calls made by non-churn users who do not have international plan:
df[df["Churn"] == 0 & (df["International plan"] == "No")]["Total intl minutes"].max()
# Out:
# np.float64(18.9)

# %% [markdown]
# <h2>Row Indexing</h2>

# %%
# This can be done using loc and iloc
# LOC>>>
df.loc[5]
# Out:
# State                        AL
# Account length              118
# Area code                   510
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         223.4
# Total day calls              98
# Total day charge          37.98
# Total eve minutes         220.6
# Total eve calls             101
# Total eve charge          18.75
# Total night minutes       203.9
# Total night calls           118
# Total night charge         9.18
# Total intl minutes          6.3
# Total intl calls              6
# Total intl charge           1.7
# Customer service calls        0
# Churn                         0
# Name: 5, dtype: object

# %%
# lets try geting a range of indices and a range of rows too
# can be done in two ways 
# 1}
df.loc[0:5, "State": "Area code"]
# 2}
df.iloc[0:5, 0:3]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415

# %%
df.loc[30, "State"]
# Out:
# 'IL'

# %% [markdown]
# <h1>Summary tables</h1>

# %%
# contigency tables
pd.crosstab(df["Churn"], df["International plan"])
# Out:
# International plan    No  Yes
# Churn
# 0                   2664  186
# 1                    346  137

# %%
# PIVOT TABLES
df.pivot_table(
    ["Total day calls", "Total eve calls", "Total night calls"],
    ["Area code"],
    aggfunc="mean",
)
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408             100.496420        99.788783          99.039379
# 415             100.576435       100.503927         100.398187
# 510             100.097619        99.671429         100.601190
